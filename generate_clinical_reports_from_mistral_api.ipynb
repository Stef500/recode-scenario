# %% [markdown]
# <a href="https://colab.research.google.com/github/24p11/recode-scenario/blob/main/generate_clinical_reports.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import re
import ast
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
scenario_file_name = "generated_scenarios_20250922_1207.csv"
result_file_name = "test_20250922"

# %%
nb_samples = 12

# %%
path_ref = "/content/drive/MyDrive/Results/clinical_reports/"

# %%
df_scenarios= pd.read_csv("/content/drive/MyDrive/Scenario/data/" + scenario_file_name,index_col=0)

# %%
#!pip install mistralai

# %%
import requests
import time
import logging
from tenacity import retry, stop_after_attempt, wait_exponential

# %%
import os
from mistralai import Mistral

# %%
api_url = "https://api.mistral.ai/v1/chat"

model = "mistral-large-latest"

# %%
client = Mistral(api_key=api_key)

# %%
from io import BytesIO
from mistralai import File
import json
import time

# %%
import argparse
import json
import os
import random
import time
from io import BytesIO

import httpx
from mistralai import File, Mistral


def create_client():
    """
    Create a Mistral client using the API key from environment variables.

    Returns:
        Mistral: An instance of the Mistral client.
    """
    return Mistral(api_key=os.environ["MISTRAL_API_KEY"])

def generate_random_string(start, end):
    """
    Generate a random string of variable length.

    Args:
        start (int): Minimum length of the string.
        end (int): Maximum length of the string.

    Returns:
        str: A randomly generated string.
    """
    length = random.randrange(start, end)
    return ' '.join(random.choices('abcdefghijklmnopqrstuvwxyz', k=length))

def print_stats(batch_job):
    """
    Print the statistics of the batch job.

    Args:
        batch_job: The batch job object containing job statistics.
    """
    print(f"Total requests: {batch_job.total_requests}")
    print(f"Failed requests: {batch_job.failed_requests}")
    print(f"Successful requests: {batch_job.succeeded_requests}")
    print(
        f"Percent done: {round((batch_job.succeeded_requests + batch_job.failed_requests) / batch_job.total_requests, 4) * 100}")


def create_input_file(client, data):
    """
    Create an input file for the batch job.

    Args:
        client (Mistral): The Mistral client instance.
        num_samples (int): Number of samples to generate.

    Returns:
        File: The uploaded input file object.
    """
    buffer = BytesIO()
    for idx in range(len(data)):
        request = {
            "custom_id": str(idx),
            "body": {
                "max_tokens":  128_000,
                "messages":  [
                    {
                        "role": "system",
                        "content": data.iloc[idx]["system_prompt"]
                        },
                    {
                        "role": "user",
                        "content": data.iloc[idx]["user_prompt"]
                        },
                    {
                        "role": "assistant",
                        "content": data.iloc[idx]["prefix"],
                        "prefix": True
                        },
                    ]
            }
        }
        buffer.write(json.dumps(request).encode("utf-8"))
        buffer.write("\n".encode("utf-8"))
    return client.files.upload(file=File(file_name="file.jsonl", content=buffer.getvalue()), purpose="batch")


def run_batch_job(client, input_file, model):
    """
    Run a batch job using the provided input file and model.

    Args:
        client (Mistral): The Mistral client instance.
        input_file (File): The input file object.
        model (str): The model to use for the batch job.

    Returns:
        BatchJob: The completed batch job object.
    """
    batch_job = client.batch.jobs.create(
        input_files=[input_file.id],
        model=model,
        endpoint="/v1/chat/completions",
        metadata={"job_type": "testing"}
    )

    while batch_job.status in ["QUEUED", "RUNNING"]:
        batch_job = client.batch.jobs.get(job_id=batch_job.id)
        #print_stats(batch_job)
        time.sleep(1)

    print(f"Batch job {batch_job.id} completed with status: {batch_job.status}")
    return batch_job


def download_file(client, file_id, output_path):
    """
    Download a file from the Mistral server.

    Args:
        client (Mistral): The Mistral client instance.
        file_id (str): The ID of the file to download.
        output_path (str): The path where the file will be saved.
    """
    if file_id is not None:
        print(f"Downloading file to {output_path}")
        output_file = client.files.download(file_id=file_id)
        with open(output_path, "wb") as f:
            for chunk in output_file.stream:
                f.write(chunk)
        print(f"Downloaded file to {output_path}")

# %%
for i in range(0, int(len(df_scenarios)/nb_samples)):
  print(str(i*nb_samples) + " - "+ str((i+1)*nb_samples) )
  prompts = df_scenarios[i*nb_samples:(i+1)*nb_samples].reset_index(drop=True)
  input_file = create_input_file(client, prompts)
  print(f"Created input file {input_file}")
  batch_job = run_batch_job(client, input_file, model)
  print(f"Job duration: {batch_job.completed_at - batch_job.created_at} seconds")
  download_file(client, batch_job.output_file, path_ref + result_file_name+"/batch_" +  str(i) + ".json" )
  prompts.to_csv(path_ref + result_file_name+"/batch_" +  str(i) + ".csv" )
# Out:
# 0 - 12
# Created input file id='b4b8c8dd-15cb-4117-b9e3-5681e0d733d2' object='file' size_bytes=104998 created_at=1758535859 filename='file.jsonl' purpose='batch' sample_type='batch_request' source='upload' num_lines=12 mimetype='application/jsonl' signature='5f86690de80ba355'
# Batch job e47f57fa-ce9c-46d6-9650-a9705e2d9163 completed with status: SUCCESS
# Job duration: 109 seconds
# Downloading file to /content/drive/MyDrive/Results/clinical_reports/test_20250922/batch_0.json
# Downloaded file to /content/drive/MyDrive/Results/clinical_reports/test_20250922/batch_0.json

# %%
import os
import json

df_res_final=pd.DataFrame()

p = re.compile("```")

output_dir = path_ref + "/"+result_file_name + "/"
for i in range(int(len(df_scenarios)/nb_samples) ): # Iterate through all batch files
    file_path = os.path.join(output_dir, f"batch_{i}.json")
    if os.path.exists(file_path):
        results = []
        with open(file_path, "r", encoding="utf-8") as f:
            for line in f:
                results.append(json.loads(line.strip()))

        # Assuming extract_response is defined and works correctly
        # and results contains the data structure as seen in the previous outputs

        prep_dict=[]
        for result_item in results:
            # Check if the item has a response and extract it
            if "response" in result_item and result_item["response"] and "body" in result_item["response"] and "choices" in result_item["response"]["body"]:
                message_content=result_item["response"]["body"]["choices"][0]["message"]["content"]
                if len(message_content)<40:
                  continue
                m = p.finditer(message_content)
                positions = [i.span() for i in m]
                if len(positions) == 1:
                  res = message_content[positions[0][1]+4:]
                else:
                  res = message_content[positions[0][1]+4:positions[1][0]]

                prep_dict.append({"bacth":i,"num_in_":result_item['custom_id'],"crh":res})

        df_scenarios_save = pd.read_csv(path_ref + result_file_name+"/batch_" +  str(i) + ".csv",index_col=0)
        df_res_tmp = pd.DataFrame(prep_dict)
        df_res_tmp["num_in_"]=  df_res_tmp["num_in_"].astype(int)
        df_res_tmp = df_scenarios_save.merge(df_res_tmp,right_on="num_in_",left_index=True)
        df_res_final = pd.concat([df_res_final,df_res_tmp])

# %%
df_res_final.to_csv(path_ref + result_file_name + "/crh_"+result_file_name+".csv")

# %%
print(df_res_final.iloc[1,len(df_res_final.columns)-7])
print(df_res_final.iloc[1,len(df_res_final.columns)-1])
# Out:
# **SCÉNARIO DE DÉPART :**
# - Âge du patient : 53 ans
# - Sexe du patient : Masculin
# - Date d'entrée : 27/03/2024
# - Date de sortie : 06/04/2024
# - Date de naissance : 10/10/1970
# - Prénom du patient : Germain
# - Nom du patient : Atamian
# - Contexte de l'hospitalisation : Prise en charge chirugicale en hospitalisation complète pour - exérèse de lésion d'un ventricule latéral cérébral, par craniotomie (abfa005)
# . HOSPITALISATION POUR TRAITEMENT.  La situation est celle d’un patient atteint d’une affection connue, diagnostiquée avant l’admission, hospitalisé pour le traitement de celle-ci. Les circonstances du diagnostic préalable n’importent pas : le diagnostic de l’affection a pu être fait par un médecin généraliste ou spécialiste « de ville », par un service médical d’urgence et de réanimation (SMUR), lors du passage dans une structure d’accueil des urgences, lors d’un séjour précédent dans une autre unité médicale, y compris l’unité d’hospitalisation de courte durée, du même établissement de santé ou d’un autre, etc. La situation de traitement est présente lorsque le diagnostic de l’affection est fait au moment de l’entrée du patient dans l’unité médicale et que l’admission a pour but le traitement de l’affection. La situation est celle d'une hospitalisation pour traitement unique chirurgical. Le diagnostic résultant de l'intervention peut être différent du diagnostic préopératoire.
#
# - Codage CIM10 :
#    * Diagnostic principal : Tumeur maligne du cerveau, sauf lobes et ventricules (C710)
#    * Diagnostic associés :
# - Trouble organique de la personnalité (F070)
# - Autres formes de cardiopathie ischémique chronique (I258)
# - Aphasie récente, persistant au-delà de 24 heures (R4700)
# - Tumeur maligne secondaire du cerveau et des méninges cérébrales (C793)
# - Tumeur maligne secondaire des os et de la moelle osseuse (C795)
# - Antécédents personnels d'utilisation (actuelle) à long terme d'anticoagulants (Z921)
#
# * Acte CCAM :
# - exérèse de lésion d'un ventricule latéral cérébral, par craniotomie (abfa005)
#
# - Localisation anatomique de la tumeur primaire : Tumeur maligne du cerveau, sauf lobes et ventricules (C710)
# - Mode d'entrée' : DOMICILE
# - Mode de sortie' : DOMICILE
# - Score TNM : Si la notion de score de TNM est pertinente avec le type histologique et la localisation anatomique, vous choisirez un score TNM
# - Type anatomopathologique de la tumeur primaire : Vous choisirez vous même un type histologique cohérent avec la localisation anatomique
# - Biomarqueurs tumoraux : Vous choisirez des biomarqueurs tumoraux cohérents avec la localisation anatomique et l'histologie de la tumeur
# - Hôpital : Hôpital Roger Salengro - Centre Hospitalier Universitaire de Lille
# - Nom du médecin / signataire : Marie Bendotti
# - Service : NEURO-CHIRURGIE
# Ce cas clinique concerne un patient présentant un cancer
# Veillez à bien préciser le type histologique et la valeur des biomarqueurs si recherchés
#
#
# {
#   "CR": "
# ## Compte rendu opératoire
#
# **Patient :** Germain Atamian, 53 ans
# **Date d’intervention :** 28/03/2024
# **Opérateur :** Dr Marie Bendotti
# **Service :** Neurochirurgie, Hôpital Roger Salengro - CHU de Lille
#
# ---
#
# ### Diagnostic
# Exérèse d’une lésion tumorale du ventricule latéral gauche chez un patient porteur d’un gliome infiltrant du parenchyme cérébral, avec métastases cérébrales et osseuses connues. L’indication opératoire était motivée par une lésion volumineuse du ventricule latéral gauche, responsable d’une hydrocéphalie obstructive symptomatique (céphalées rebelles, troubles de la marche, et altération cognitive progressive). L’IRM cérébrale récente montrait une progression de la lésion malgré une ligne de chimiothérapie par témozolomide.
#
# ---
#
# ### Technique utilisée
# Craniotomie pariétale gauche sous anesthésie générale, avec neuronavigation (StealthStation S8, Medtronic) et monitoring peropératoire des potentiels évoqués moteurs (PEM). L’abord a été planifié en préopératoire sur les séquences IRM en T1 avec gadolinium et FLAIR, avec repérage des zones éloquentes par tractographie. Après ouverture de la dure-mère, une corticectomie limitée a permis d’aborder le ventricule latéral. La lésion, blanchâtre, friable et vascularisée, était adhérente à la paroi ventriculaire et au plexus choroïde, sans infiltration macroscopique du thalamus adjacent. L’exérèse a été réalisée en bloc après coagulation bipolaire des vaisseaux nourriciers, avec contrôle hémostatique par Surgicel® et colle biologique (TachoSil®). Un cathéter de dérivation ventriculaire externe (DVE) a été posé en fin d’intervention en prévision d’une hydrocéphalie postopératoire.
#
# ---
# ### Constatations per-opératoires
# - **Caractères de la lésion** : Masse intraventriculaire gauche de 3,5 cm de grand axe, polylobée, à limites imprécises avec le parenchyme périventriculaire. Aspect hémorragique par endroits, suggérant des remaniements nécrotiques. Pas d’envahissement visible du septum pellucidum ou du foramen de Monro.
# - **Difficultés techniques** : Saignement modéré lors de la dissection du plexus choroïde, contrôlé par coagulation bipolaire et application de matrice hémostatique (FloSeal®). La proximité du faisceau cortico-spinal a nécessité une prudence accrue, avec adaptation des paramètres de stimulation pour les PEM (intensité réduite à 12 mA).
# - **Zones atteintes/saines** : La lésion semblait centrée sur la corne frontale du ventricule latéral, sans extension macroscopique vers les noyaux gris centraux. Le parenchyme cérébral adjacent était œdématié mais sans signe franc d’infiltration tumorale.
#
# ---
# ### Matériels utilisés
# - **Neuronavigation** : StealthStation S8 (Medtronic) avec fusion d’images IRM (T1-Gd et FLAIR).
# - **Monitoring neurophysiologique** : Neuro-MEP (Natus®) pour les potentiels évoqués moteurs, avec électrodes sous-corticaux et couronnes de stimulation.
# - **Instrumentation** : Micro-instruments (KLS Martin), aspirateur ultrasonique (CUSA, Integra), et système de coagulation bipolaire (Erbe).
# - **Hémostase** : Surgicel®, TachoSil®, et FloSeal® pour les zones à risque hémorragique.
# - **Dérivation** : Kit de DVE (Medtronic) avec valve de niveau 10 cmH2O, positionné en regard de la corne frontale controlatérale.
#
# ---
#
# ## Compte rendu d’hospitalisation
#
# **Patient :** Germain Atamian, 53 ans, homme
# **Dates d’hospitalisation :** Du 27/03/2024 au 06/04/2024
# **Service :** Neurochirurgie, Hôpital Roger Salengro - CHU de Lille
# **Médecin référent :** Dr Marie Bendotti
#
# ---
#
# ### Motif d’hospitalisation
# Prise en charge chirurgicale programmée pour exérèse d’une lésion tumorale du ventricule latéral gauche, dans le cadre d’un gliome de haut grade métastatique (métastases cérébrales et osseuses connues). Le patient présentait une aggravation récente de son état général, avec céphalées invalidantes, troubles de la marche, et une aphasie expressive partielle apparue 3 semaines avant l’admission. L’IRM cérébrale du 20/03/2024 objectivait une progression de la lésion intraventriculaire malgré 6 cycles de témozolomide (2e ligne de traitement), justifiant une résection chirurgicale en urgence relative.
#
# ---
#
# ### Antécédents
# - **Médicaux** :
#   - Gliome infiltrant du parenchyme cérébral diagnostiqué en 10/2022 (histologie : astrocytome anaplasique IDH-muté, grade III OMS), traité par radiothérapie conformationnelle (60 Gy) + témozolomide (1re ligne, 12 cycles jusqu’en 04/2023).
#   - Récidive en 07/2023 avec transformation en glioblastome (grade IV OMS), métastases osseuses (rachis dorsal et bassin) et cérébrales (2 lésions frontales controlatérales). Traitement par lomustine (2e ligne, 6 cycles jusqu’en 03/2024).
#   - Cardiopathie ischémique chronique (IDM en 2018, FEVG à 45 % sous bêta-bloquants), et trouble organique de la personnalité post-AVC (2019, séquelles cognitives légères).
#   - Traitement anticoagulant au long cours par apixaban (5 mg x2/j) pour FA paroxystique.
# - **Chirurgicaux** : Appendicectomie (1995), pose de 2 stents coronaires (2018).
# - **Familiaux** : Père décédé d’un cancer bronchique à 62 ans ; mère vivante, HTA.
# - **Allergies** : Aucune connue.
#
# ---
# ### Mode de vie
# - **Toxiques** : Tabagisme sevré en 2022 (30 paquets-année), consommation d’alcool occasionnelle (1-2 verres de vin/semaine).
# - **Profession** : Ancien technicien de maintenance (arrêt maladie depuis 2023).
# - **Autres** : Sédentaire (ECOG 2), vie en couple sans enfant. Poids stable à 78 kg pour 1,75 m (IMC 25,5). Pas de suivi diététique spécifique.
#
# ---
# ### Histoire de la maladie
# Le patient a été diagnostiqué en octobre 2022 pour un gliome du lobe frontal gauche, initialement classé comme astrocytome anaplasique (grade III OMS, mutation IDH1 R132H, MGMT méthylé). Après chirurgie partielle et radio-chimiothérapie concomitante (témozolomide), une récidive locale a été objectivée en juillet 2023, avec transformation en glioblastome (grade IV, amplification d’EGFR, non méthylé pour MGMT). Un bilan d’extension retrouvait alors des métastases osseuses (scintigraphie osseuse) et cérébrales (IRM). Une 2e ligne par lomustine a été initiée, mais l’évaluation récente montrait une progression des lésions intraventriculaires (doubling time estimé à 3 mois sur les IRM successives), motivant cette hospitalisation pour exérèse.
#
# ---
# ### Examen clinique (à l’admission, 27/03/2024)
# - **Constantes** : PA 135/80 mmHg, FC 88 bpm (rythme irrégulier, FA), SpO2 97 % en air ambiant, T° 36,8°C.
# - **Neurologique** :
#   - Vigilance normale (GCS 15), mais ralentissement idéomoteur.
#   - Aphasie expressive modérée (score de Boston à 70/100), sans trouble de compréhension.
#   - Déficit moteur léger du membre inférieur droit (4+/5), réflexes vifs symétriques, pas de signe de Babinski.
#   - Marche talonnante possible mais instable (ataxie cérébelleuse légère).
# - **Cardiaque** : Souffle systolique 2/6, pas de signe d’IC.
# - **Poids** : 78 kg (stable vs. dernier poids connu).
#
# ---
# ### Examens complémentaires
# - **Biologie (27/03/2024)** :
#   - NFS : Hb 12,8 g/dL, leucocytes 6 200/mm³ (PNN 60 %), plaquettes 210 000/mm³.
#   - Créatinine 88 µmol/L (DFG > 60 mL/min), bilan hépatique normal (ASAT/ALAT/TP dans les normes).
#   - INR à 1,8 (sous apixaban, arrêté 48h avant la chirurgie).
# - **IRM cérébrale (20/03/2024)** :
#   - Lésion intraventriculaire gauche mesurant 35 x 28 mm (vs. 25 x 20 mm en 12/2023), rehaussée après gadolinium, avec effet de masse sur le foramen de Monro et hydrocéphalie triventriculaire modérée.
#   - Deux autres lésions métastatiques frontales (10 et 15 mm), stables.
#   - Pas de signe d’engagement.
# - **Scintigraphie osseuse (05/03/2024)** : Foyers hyperfixants au rachis dorsal (D6-D7) et aile iliaque droite, compatibles avec des métastases connues.
#
# ---
# ### Évolution pendant l’hospitalisation
# - **27/03/2024** : Admission en neurochirurgie. Arrêt de l’apixaban, relais par HBPM à dose curative (énoxaparine 60 mg x2/j). Prémédication par dexaméthasone (4 mg x2/j) pour réduire l’œdème périlésionnel.
# - **28/03/2024** : Craniotomie pariétale gauche avec exérèse macroscopiquement complète de la lésion intraventriculaire (voir CR opératoire). Pose d’un DVE en peropératoire. Transfert en réanimation pour surveillance postopératoire immédiate (extubation sans difficulté).
# - **29/03/2024** :
#   - **Réanimation** : Stable sur le plan hémodynamique. Diurèse conservée, pas de signe de resaignement. Scanner cérébral de contrôle : pas d’hématome postopératoire, DVE fonctionnel (niveau ventriculaire abaissé).
#   - **Neurologie** : Aphasie inchangée, déficit moteur droit légèrement amélioré (4+/5 → 5-/5). Reprise de l’alimentation orale progressive.
# - **30/03/2024** : Transfert en unité de neurochirurgie. Retrait du DVE (débit < 30 mL/24h, patient asymptomatique). Reprise de la dexaméthasone en décroissance (4 mg/j).
# - **31/03/2024 à 05/04/2024** :
#   - **Kinésithérapie** : Rééducation de la marche (déambulation autonome avec canne).
#   - **Orthophonie** : Séances quotidiennes pour l’aphasie (amélioration de la fluence).
#   - **Biologie** : NFS stable, créatinine normale. Reprise de l’apixaban à J5 postopératoire.
#   - **Imagerie** : IRM de contrôle (04/04/2024) : lit opératoire sans résidu tumoral visible, hydrocéphalie résolutive. Stabilité des autres lésions métastatiques.
# - **06/04/2024** : Sortie à domicile avec :
#   - Traitement : apixaban 5 mg x2/j, dexaméthasone 2 mg/j (arrêt prévu en 1 semaine), paracétamol si besoin.
#   - Suivi : Consultation en neuro-oncologie prévue le 15/04/2024 pour discussion d’une 3e ligne thérapeutique (bevacizumab ?), et IRM de contrôle à 1 mois.
#
# ---
# ### Conclusion
# Hospitalisation pour exérèse chirurgicale réussie d’une lésion intraventriculaire gauche dans le cadre d’un glioblastome métastatique en progression sous chimiothérapie. Évolution postopératoire simple, avec amélioration des symptômes neurologiques (marche, aphasie). Le patient rentre à domicile en bon état général (ECOG 1), avec un projet thérapeutique à discuter en RCP oncologique (options : bevacizumab, re-chirurgie stéréotaxique, ou soins de support). La prise en charge multidisciplinaire (kiné, orthophonie) sera poursuivie en ambulatoire.
#
# ",
#
#   "formulations": {
#     "diagnostics": {
#       "C710 - Tumeur maligne du cerveau, sauf lobes et ventricules": [
#         "gliome infiltrant du parenchyme cérébral",
#         "glioblastome (grade IV OMS)",
#         "astrocytome anaplasique IDH-muté (grade III OMS)",
#         "lésion tumorale du ventricule latéral gauche",
#         "lésion intraventriculaire gauche",
#         "masse intraventriculaire gauche",
#         "récidive locale avec transformation en glioblastome"
#       ],
#       "F070 - Trouble organique de la personnalité": [
#         "trouble organique de la personnalité post-AVC",
#         "séquelles cognitives légères"
#       ],
#       "I258 - Autres formes de cardiopathie ischémique chronique": [
#         "cardiopathie ischémique chronique",
#         "IDM en 2018",
#         "FEVG à 45 %",
#         "souffle systolique 2/6"
#       ],
#       "R4700 - Aphasie récente, persistant au-delà de 24 heures": [
#         "aphasie expressive partielle",
#         "aphasie expressive modérée",
#         "troubles du langage",
#         "score de Boston à 70/100"
#       ],
#       "C793 - Tumeur maligne secondaire du cerveau et des méninges cérébrales": [
#         "métastases cérébrales connues",
#         "2 lésions frontales controlatérales (métastatiques)",
#         "foyers métastatiques cérébraux"
#       ],
#       "C795 - Tumeur maligne secondaire des os et de la moelle osseuse": [
#         "métastases osseuses (rachis dorsal et bassin)",
#         "foyers hyperfixants au rachis dorsal (D6-D7) et aile iliaque droite",
#         "localisations osseuses secondaires"
#       ],
#       "Z921 - Antécédents personnels d'utilisation (actuelle) à long terme d'anticoagulants": [
#         "traitement anticoagulant au long cours par apixaban",
#         "sous apixaban (5 mg x2/j) pour FA paroxystique",
#         "relais par HBPM à dose curative (énoxaparine)"
#       ]
#     },
#
#     "informations": {
#       "Date entrée": ["27/03/2024"],
#       "Date de sortie": ["06/04/2024"],
#       "Service d'hospitalisation": [
#         "Neurochirurgie, Hôpital Roger Salengro - CHU de Lille",
#         "unité de neurochirurgie"
#       ],
#       "Nom/Prénom du médecin": ["Dr Marie Bendotti", "Marie Bendotti"],
#       "Nom/Prénom du patient": ["Germain Atamian"],
#       "Âge": ["53 ans"],
#       "Sexe": ["homme", "masculin"],
#       "État général": [
#         "ECOG 2 à l’admission",
#         "ECOG 1 à la sortie",
#         "altération cognitive progressive",
#         "ralentissement idéomoteur",
#         "bon état général (ECOG 1)"
#       ],
#       "Poids": ["78 kg"],
#       "Comorbidités": [
#         "cardiopathie ischémique chronique (FEVG 45 %)",
#         "FA paroxystique",
#         "trouble organique de la personnalité post-AVC (2019)",
#         "IDM en 2018"
#       ],
#       "Topographie de la tumeur primaire": [
#         "gliome du lobe frontal gauche",
#         "lésion du ventricule latéral gauche",
#         "corne frontale du ventricule latéral gauche"
#       ],
#       "Histologie tumorale": [
#         "astrocytome anaplasique IDH-muté (grade III OMS, 2022)",
#         "glioblastome (grade IV OMS, 2023)",
#         "amplification d’EGFR",
#         "MGMT non méthylé (2023)",
#         "MGMT méthylé (2022)"
#       ],
#       "Stade tumoral": [
#         "glioblastome métastatique (cT4N1M1)",
#         "métastases cérébrales et osseuses"
#       ],
#       "Biomarqueurs tumoraux": [
#         "mutation IDH1 R132H (diagnostic initial)",
#         "MGMT méthylé (2022) puis non méthylé (2023)",
#         "amplification d’EGFR (2023)"
#       ],
#       "Sites métastatiques": [
#         "métastases cérébrales (2 lésions frontales)",
#         "métastases osseuses (rachis dorsal D6-D7, aile iliaque droite)"
#       ],
#       "Évolutivité tumorale": [
#         "progression de la lésion intraventriculaire (doubling time ~3 mois)",
#         "aggravation récente des céphalées et de l’aphasie",
#         "lésion passant de 25 x 20 mm (12/2023) à 35 x 28 mm (03/2024)",
#         "résistance à la 2e ligne de chimiothérapie (lomustine)"
#       ],
#       "Examens pour diagnostic initial": [
#         "IRM cérébrale (10/2022)",
#         "biopsie stéréotaxique (2022)"
#       ],
#       "Examens d'évaluation du stade tumoral": [
#         "IRM cérébrale avec gadolinium (2022, 2023, 2024)",
#         "scintigraphie osseuse (07/2023, 03/2024)",
#         "TDM corps entier (07/2023)"
#       ],
#       "Examens d’évaluation de l’évolutivité tumorale": [
#         "IRM cérébrale comparative (12/2023 vs. 03/2024)",
#         "mesure du doubling time (~3 mois)",
#         "évaluation clinique (aggravation de l’aphasie et des céphalées)"
#       ],
#       "Traitements antitumoraux": [
#         "chirurgie (craniotomie avec exérèse, 2022 et 2024)",
#         "radiothérapie conformationnelle (60 Gy, 2022)",
#         "chimiothérapie par témozolomide (1re ligne, 12 cycles)",
#         "lomustine (2e ligne, 6 cycles)"
#       ],
#       "Lignes de traitement antitumoral": [
#         "1re ligne : radiothérapie + témozolomide (2022-2023)",
#         "2e ligne : lomustine (2023-2024)",
#         "discussion d’une 3e ligne (bevacizumab ?)"
#       ],
#       "Médicaments antitumoraux": [
#         "témozolomide (12 cycles)",
#         "lomustine (6 cycles)",
#         "bevacizumab (envisagé)"
#       ],
#       "Cycles de chimiothérapie": [
#         "12 cycles de témozolomide (1re ligne)",
#         "6 cycles de lomustine (2e ligne)"
#       ],
#       "NFS": [
#         "Hb 12,8 g/dL",
#         "leucocytes 6 200/mm³ (PNN 60 %)",
#         "plaquettes 210 000/mm³"
#       ],
#       "Créatinine": [
#         "88 µmol/L (DFG > 60 mL/min)"
#       ],
#       "Bilan hépatique": [
#         "ASAT/ALAT/TP dans les normes"
#       ]
#     }
#   }
# }

# %%
# Out:
# Index(['age', 'cage', 'cage2', 'sexe', 'date_entry', 'date_discharge',
#        'date_of_birth', 'first_name', 'last_name', 'icd_primary_code',
#        'icd_primary_description', 'icd_parent_code', 'case_management_type',
#        'case_management_type_description', 'case_management_type_text',
#        'drg_parent_code', 'drg_parent_description', 'icd_secondaray_code',
#        'text_secondary_icd_official', 'procedure', 'text_procedure',
#        'admission_type', 'admission_mode', 'discharge_disposition', 'dms',
#        'los_mean', 'los_sd', 'cancer_stage', 'score_TNM', 'histological_type',
#        'treatment_recommandation', 'chemotherapy_regimen', 'biomarkers',
#        'first_name_med', 'last_name_med', 'department', 'hospital',
#        'cd_md_pec', 'user_prompt', 'system_prompt', 'prefix', 'prefix_len',
#        'bacth', 'num_in_', 'crh'],
#       dtype='object')

# %%
df_res_final.crh
# Out:
# 0     \n{\n  "CR": "\n---\n**Hôpital Larrey - Centre...
# 1     \n{\n  "CR": "\n### Motif d’hospitalisation\nB...
# 2     \n{\n  "CR": "\n## Compte rendu opératoire\n\n...
# 3     \n{\n  "CR": "\n## Compte rendu opératoire\n\n...
# 4     \n{\n  "CR": "\n**Hôpital Bichat-Claude Bernar...
# 5     \n{\n  "CR": "\n**Hôpital Nord - Assistance Pu...
# 6     \n{\n  "CR": "\n### Motif d’hospitalisation\nM...
# 7     \n{\n  "CR": "\n**Hôpital Michallon - CHU Gren...
# 8     \n{\n  "CR": "\n**SERVICE DE PHYSIOLOGIE**\n**...
# 9     \n{\n  "CR": "\n**SERVICE D’ORL INFANTILE**\n*...
# 10    \n{\n  "CR": "\n## Compte rendu opératoire\n\n...
# 11    \n{\n  "CR": "\n## Compte rendu opératoire\n\n...
# Name: crh, dtype: object
