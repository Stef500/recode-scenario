# %% [markdown]
# <a href="https://colab.research.google.com/github/24p11/recode-scenario/blob/main/scenario_oncology_v2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Create fictive clinical notes from Code set (DRG + ICD)
#
# Code set are the raw classification data, we can extract from National database (Base nationale PMSI en France). They are made of
# * classification profile made of grouping variables from DRG records which are prepared with their frequency in the national database
#     - age (class)
#     - sexe
#     - DRG (racine GHM)
#     - Main diagnosis (ICD10) : cf
#     - Hospitalization management type : cf
# * diagnosis associated to each classification profile, extracted with their frequencies
# * procedures associated to each classification profile, specialy for surgery and technical gestures, extracted with their frequencies
#
# From thoses raw information we produce a coded clinical scenario which will be uses a seed.
#
# This scenario is transformed into a detail prompt that will be given to a LLM for generation.
# From the combinaision of primary and related diagnosis in French discharge abstract, we derived two notions :
# * Primary diagnosis : host the notion of principal pathology, it is rather the primary diagnosis of the discharge abstract or the related diagnosis when it exists and that the primary diagnosis of the discharge abstract is from the chapter "Facteurs influant sur l’état de santé" of ICD10
# * The Hospitalization management type is rather the term "Primary diagnosis" or the ICD-10 code of the related diagnosis when it exists

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import pandas as pd
import numpy as np
import datetime as dt

# %%
from utils import *

# %%
gs = generate_scenario()
# Load official dictionaries
# col_names option allow you to algin your column names the project dictionary.
gs.load_offical_icd("cim_2024.xlsx",col_names={"code" : "icd_code","libelle":"icd_code_description"} )
gs.load_offical_procedures("ccam_actes_2024.xlsx",col_names={"code":"procedure","libelle_long":"procedure_description"} )
col_names={"Code CIM":"icd_parent_code","Localisation":"primary_site","Type Histologique":"histological_type",
           "Stade":"stage","Marqueurs Tumoraux":"biomarkers","Traitement":"treatment_recommandation","Protocole de Chimiothérapie":"chemotherapy_regimen"}
gs.load_cancer_treatement_recommandations("Tableau récapitulatif traitement cancer.xlsx",col_names ) 
col_names={"racine":"drg_parent_code","lib_spe_uma":"specialty","ratio_spe_racine":"ratio"}
gs.load_specialty_refential("dictionnaire_spe_racine.xlsx",col_names)
gs.load_referential_hospital("chu")

# %%
# Load data from BN  PMSI
col_names={"racine":"drg_parent_code","das": "icd_secondary_code","diag":"icd_primary_code","categ_cim":"icd_primary_parent_code",
            "mdp":"case_management_type","nb_situations":"nb","acte":"procedure",
            "mode_entree":"admission_mode",
            "mode_sortie":"discharge_disposition",
            "mode_hospit":"admission_type"}
gs.load_classification_profile("bn_pmsi_cases_20250819.csv", col_names)
gs.load_secondary_icd("bn_pmsi_related_diag_20250818.csv",col_names)
gs.load_procedures("bn_pmsi_procedures_20250818.csv",col_names)

# %%
#Prepare cases
# df_profile = gs.df_classification_profile.drop(columns="nb")
df_profile = gs.df_classification_profile
df_profile = df_profile[(df_profile.icd_primary_code.isin(gs.icd_codes_cancer) )  & (~df_profile.drg_parent_code.isin(gs.drg_parent_code_radio) ) ]

# %%
def create_system_prompt(scenario):
    if scenario['admission_type'] == "Inpatient" and scenario['drg_parent_code'][2:3]=="C" :
        template_name = "surgery_complete.txt"
    elif scenario['admission_type'] == "Outpatient" and scenario['drg_parent_code'][2:3]=="C" :
        template_name = "surgery_outpatient.txt"
    else:
        template_name = "scenario_onco_v1.txt"
        
    with open("templates/" + template_name, "r", encoding="utf-8") as f:
        prompt = f.read()
    
    return prompt

# %%
# col_names = ["icd_primary_code", "case_management_type", "drg_parent_code", "cage2","cage", "sexe", "admission_type","admission_mode", "discharge_disposition",
#              "dms", "los_mean", "los_sd", "drg_parent_description"]
# test_generation_v1 = df_profile.sample(20)[col_names].reset_index(drop=True)
test_generation_v1 = df_profile.sample(1000, weights="nb").reset_index(drop=True)
test_generation_v1
# Out:
#     icd_primary_code case_management_type drg_parent_code    age     cage  \
# 0               C444                 Z080           09M12  ge_18    [80-[
# 1                C20                   DP           06K04  ge_18  [50-60[
# 2               C349                 Z511           28Z07  ge_18  [70-80[
# 3                C61                   DP           12K06  ge_18  [60-70[
# 4                C50                   DP           09C20  ge_18  [50-60[
# ..               ...                  ...             ...    ...      ...
# 995             C833                   DP           17C08  ge_18    [80-[
# 996             C159                 Z511           28Z07  ge_18  [60-70[
# 997              C73                   DP           10C11  ge_18  [40-50[
# 998             C443                   DP           09C23  ge_18  [70-80[
# 999             D069                   DP           13C11  ge_18  [40-50[
#
#        cage2  sexe admission_type admission_mode discharge_disposition  ...  \
# 0      [50-[     1     Outpatient       DOMICILE              DOMICILE  ...
# 1      [50-[     1     Outpatient       DOMICILE              DOMICILE  ...
# 2      [50-[     2     Outpatient       DOMICILE              DOMICILE  ...
# 3      [50-[     1     Outpatient       DOMICILE              DOMICILE  ...
# 4      [50-[     2     Outpatient       DOMICILE              DOMICILE  ...
# ..       ...   ...            ...            ...                   ...  ...
# 995    [50-[     2     Outpatient       DOMICILE              DOMICILE  ...
# 996    [50-[     1     Outpatient       DOMICILE              DOMICILE  ...
# 997  [18-50[     2     Outpatient       DOMICILE              DOMICILE  ...
# 998    [50-[     1     Outpatient       DOMICILE              DOMICILE  ...
# 999  [18-50[     2     Outpatient       DOMICILE              DOMICILE  ...
#
#                             libelle_da gp_cas  \
# 0    Tissu cutané et tissu sous-cutané    X16
# 1                             Digestif    K02
# 2                              Séances    S02
# 3           Uro-néphrologie et génital    K10
# 4                   Gynécologie - sein    C18
# ..                                 ...    ...
# 995                        Hématologie    C21
# 996                            Séances    S02
# 997                     Endocrinologie    C22
# 998  Tissu cutané et tissu sous-cutané    C26
# 999                 Gynécologie - sein    C17
#
#                                         libelle_gp_cas    ga  \
# 0       Affections et traumatismes de la peau, gelures  G168
# 1    Endoscopies digestives et biliaires avec ou sa...  G022
# 2                           Chimiothérapie pour tumeur  G190
# 3    Aff. génito-urinaires avec Acte classant non o...  G209
# 4                                    Chirurgie du sein  G107
# ..                                                 ...   ...
# 995  Chir. pour Aff. des Org. Hématopoiétiques, Lym...  G141
# 996                         Chimiothérapie pour tumeur  G190
# 997  Chirurgie de la Thyroide, Parathyroide, du Tra...  G158
# 998                               Chirurgie de la peau  G218
# 999                            Chirurgie Gynécologique  G103
#
#                                             libelle_ga   da_gp    da_gp_ga  \
# 0    Explorations et surveillance des affections de...  D20X16  D20X16G168
# 1       Endoscopies digestives avec ou sans anesthésie  D01K02  D01K02G022
# 2                             Séances : chimiothérapie  D27S02  D27S02G190
# 3    Séjours comprenant une biopsie prostatique, en...  D15K10  D15K10G209
# 4                 Chirurgie pour tumeurs malignes sein  D12C18  D12C18G107
# ..                                                 ...     ...         ...
# 995  Chirurgie au cours des tumeurs malignes (hémat...  D16C21  D16C21G141
# 996                           Séances : chimiothérapie  D27S02  D27S02G190
# 997                           Chirurgie de la thyroide  D19C22  D19C22G158
# 998              chirurgie tumeurs malignes de la peau  D20C26  D20C26G218
# 999  Chirurgie pour tumeurs malignes (app génital fem)  D12C17  D12C17G103
#
#     anseqta aso             specialty
# 0      2024   M          DERMATOLOGIE
# 1      2024   M  HEPATO-GASTRO-ENTERO
# 2      2024   M        CANCERO ADULTE
# 3      2024   C              UROLOGIE
# 4      2024   C           GYNECOLOGIE
# ..      ...  ..                   ...
# 995    2024   C  CHIR.PLAST.RECONSTR.
# 996    2024   M        CANCERO ADULTE
# 997    2024   C   CHIRURGIE VISCERALE
# 998    2024   C  CHIR.PLAST.RECONSTR.
# 999    2024   C           GYNECOLOGIE
#
# [1000 rows x 26 columns]

# %%
from tqdm import tqdm

# %%
list_scenario = []

#for i in tqdm(range(len(test_generation_v1))):
for i in tqdm(range(1)):
    profile = test_generation_v1.iloc[i].copy()
    scenario = gs.generate_scenario_from_profile(profile.drop("nb"))
    row = {k:scenario[k] for k in scenario.keys()}
    user_prompt = gs.make_prompts_marks_from_scenario(scenario)
    system_prompt = create_system_prompt(scenario)
    row["user_prompt"] = user_prompt
    row["system_prompt"] = system_prompt
    
    if  scenario["icd_primary_code"]  in gs.icd_codes_cancer  :
        prefix = """Le compte rendu suivant respecte les élements suivants :
        - les diagnostics ont une formulation moins formelle que la définition du code,
        - le type histologique et la valeur des biomarqueurs si recherchés
        - le plan du CRH est conforme aux recommandations.
        """
    else :
        prefix = """Le compte rendu suivant respecte les élements suivants :
        - les diagnostics ont une formulation moins formelle que la définition du code,
        - le type histologique et la valeur des biomarqueurs si recherchés
        - le plan du CRH est conforme aux recommandations.
        """
    
    row["prefix"] = prefix
    row["prefix_len"] = len(prefix)
    list_scenario.append(row)
# Out:
# 100%|██████████| 1/1 [00:03<00:00,  3.19s/it]

# %%
keep_cols = ['age',  'cage', 'cage2','sexe', 'date_entry', 'date_discharge', 'date_of_birth',
       'first_name', 'last_name', 'icd_primary_code', 'icd_primary_description', 'icd_parent_code',
       'case_management_type','case_management_type_description', 'case_management_type_text', 
       'drg_parent_code', 'drg_parent_description',
       'icd_secondaray_code',  'text_secondary_icd_official', 
        'procedure', 'text_procedure',
        'admission_type','admission_mode', 'discharge_disposition', 'dms', 'los_mean', 'los_sd',
       'cancer_stage', 'score_TNM', 'histological_type',
       'treatment_recommandation', 'chemotherapy_regimen', 'biomarkers',
       'first_name_med', 'last_name_med',
       'department','hospital',
       'cd_md_pec', 'user_prompt', 'system_prompt','prefix','prefix_len']
df_scenario = pd.DataFrame(list_scenario)[keep_cols]
df_scenario
# Out:
#    age   cage  cage2  sexe  date_entry date_discharge date_of_birth  \
# 0   80  [80-[  [50-[     1  2024-10-03     2024-10-03    1944-08-24
#
#   first_name last_name icd_primary_code  ... biomarkers first_name_med  \
# 0    Willyam    Traore             C444  ...       None          Ciara
#
#   last_name_med department                                           hospital  \
# 0      Sam mine       None  Hôpital Purpan - Centre hospitalier universita...
#
#   cd_md_pec                                        user_prompt  \
# 0        15  **SCÉNARIO DE DÉPART :**\n- Âge du patient : 8...
#
#                                        system_prompt  \
# 0  Vous êtes un oncologue clinicien expert. Votre...
#
#                                               prefix prefix_len
# 0  Le compte rendu suivant respecte les élements ...        287
#
# [1 rows x 42 columns]

# %%
print(df_scenario.loc[0,"user_prompt"])
# Out:
# **SCÉNARIO DE DÉPART :**
# - Âge du patient : 80 ans
# - Sexe du patient : Masculin
# - Date d'entrée : 03/10/2024
# - Date de sortie : 03/10/2024
# - Date de naissance : 24/08/1944
# - Prénom du patient : Willyam
# - Nom du patient : Traore
# - Mode de prise en charge : Hospitalisation en ambulatoire pour Examen de contrôle après traitement chirurgical d'une tumeur maligne
# - Codage CIM10 :
#    * Diagnostic principal : Tumeur maligne de la peau du cuir chevelu et du cou (C444)
#    * Diagnostic associés :
# - Sténose (de la valvule) aortique (non rhumatismale) (I350)
# - Tumeur maligne secondaire et non précisée des ganglions lymphatiques de la tête, de la face et du cou (C770)
# - Tumeur maligne secondaire d'autres sièges précisés (C798)
# - Tumeur maligne secondaire du foie et des voies biliaires intrahépatiques (C787)
# - Obésité sans précision de l'adulte avec indice de masse corporelle [IMC] égal ou supérieur à 35 kg/m² et inférieur à 40 kg/m² (E6695)
#
# - Localisation anatomique de la tumeur primaire : Tumeur maligne de la peau du cuir chevelu et du cou (C444)
# - Mode d'entrée' : DOMICILE
# - Mode de sortie' : DOMICILE
# - Score TNM : Si la notion de score de TNM est pertinente avec le type histologique et la localisation anatomique, vous choisirez un score TNM
# - Type anatomopathologique de la tumeur primaire : Vous choisirez vous même un type histologique cohérent avec la localisation anatomique
# - Biomarqueurs tumoraux : Vous choisirez des biomarqueurs tumoraux cohérents avec la localisation anatomique et l'histologie de la tumeur
# - Hôpital : Hôpital Purpan - Centre hospitalier universitaire de Toulouse
# - Nom du médecin / signataire : Ciara Sam mine
# - Service : DERMATOLOGIE
# Ce cas clinique concerne un patient présentant un cancer
# Veillez à bien préciser le type histologique et la valeur des biomarqueurs si recherchés

# %%
df_scenario.to_csv("test_generation_v2.csv")

# %%
profile
# Out:
# icd_primary_code                                                 C821
# case_management_type                                             Z511
# drg_parent_code                                                 17M06
# age                                                             ge_18
# cage                                                          [70-80[
# cage2                                                           [50-[
# sexe                                                                2
# admission_type                                              Inpatient
# admission_mode                                               DOMICILE
# discharge_disposition                                        DOMICILE
# nb                                                                 90
# dms                                              2,40000000000000e+00
# los_mean                                                     3.228022
# los_sd                                                       4.318648
# drg_parent_description               Chimiothérapie pour autre tumeur
# da                                                                D17
# libelle_da                Chimiothérapie, radiothérapie, hors séances
# gp_cas                                                            X23
# libelle_gp_cas                          Chimiothérapie (hors séances)
# ga                                                               G148
# libelle_ga                                Chimiothérapie hors séances
# da_gp                                                          D17X23
# da_gp_ga                                                   D17X23G148
# anseqta                                                          2024
# aso                                                                 M
# Name: 0, dtype: object

# %%
# df_scenario.to_csv(gs.path_data + "test_scenario_v1.csv")

# %%
import os
from mistralai import Mistral

# %%
api_key = "j17liFFXlV5X54DDPdvax0hxHBHXuSa9"
model = "mistral-large-latest"
client = Mistral(api_key=api_key)

# %%
resp = client.chat.complete(
     model = model,
    messages=[
        {"role": "system", "content": df_scenario.loc[0,"system_prompt"]},
        {"role": "user", "content": df_scenario.loc[0,"user_prompt"]},
        {"role": "assistant", "content": df_scenario.loc[0,"prefix"], "prefix": True},
    ],
)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_5592\1595699171.py in <cell line: 9>()
#       7     ],
#       8 )
# ----> 9 print(resp.choices[0].message.content[len(df_scenario.loc[0,"prefix_len"]) :])
#
# TypeError: object of type 'numpy.int64' has no len()

# %%
print(resp.choices[0].message.content[df_scenario.loc[0,"prefix_len"] :])
# Out:
# - les dates sont plausibles et cohérentes.
#
# ```json
# {
#   "CR": "
# ### Motif d’hospitalisation
# M. Willyam Traoré, 80 ans, est admis en hospitalisation de jour le 03/10/2024 pour un bilan postopératoire après exérèse d’un carcinome épidermoïde cutané du cuir chevelu. L’objectif est d’évaluer la réponse au traitement chirurgical et de dépister une éventuelle récidive ou progression métastatique, dans un contexte de métastases ganglionnaires cervicales et hépatiques connues.
#
# ### Antécédents
# Sur le plan médical, le patient présente une sténose aortique non rhumatismale, diagnostiquée en 2020 et suivie en cardiologie. Il n’a pas d’autres antécédents cardiovasculaires notables. Une obésité morbide (IMC à 37 kg/m²) est également documentée, avec un suivi nutritionnel irrégulier. Aucun antécédent chirurgical majeur en dehors de l’exérèse cutanée récente. Pas d’allergies connues.
#
# ### Mode de vie
# Ancien fumeur (30 paquets-année, sevré depuis 10 ans), sans consommation d’alcool. Retraité depuis 15 ans (ancien ouvrier dans le BTP), vivant à domicile avec son épouse. Activité physique limitée par son obésité et ses douleurs articulaires. Pas de notion de voyage récent.
#
# ### Histoire de la maladie
# En mars 2024, le patient consulte pour une lésion ulcéro-bourgeonnante du cuir chevelu, évoluant depuis 6 mois. La biopsie cutanée confirme un carcinome épidermoïde infiltrant (pT3 selon le compte-rendu anatomopathologique). Le bilan d’extension initial (TDM cervico-thoraco-abdomino-pelvien + PET-scan) révèle des adénopathies cervicales bilatérales (N2c) et des métastases hépatiques multiples (M1). Le statut PD-L1 est positif (CPS > 20), sans mutation BRAF ou EGFR détectée.
#
# Une exérèse large de la lésion primitive avec reconstruction par lambeau local est réalisée en mai 2024, suivie d’une radiothérapie adjuvante (50 Gy en 25 fractions). Aucun traitement systémique n’a été initié en première ligne, en raison de l’âge et des comorbidités.
#
# ### Examen clinique
# À l’admission, le patient est en bon état général (ECOG 1), conscient et orienté. Constantes : TA 145/85 mmHg, FC 78/min (régulière, souffle systolique 3/6 au foyer aortique), SpO₂ 96% en air ambiant, T° 36,8°C. Poids : 105 kg pour 1,72 m (IMC 35,5 kg/m²). L’examen cutané ne retrouve pas de récidive locale au niveau de la cicatrice opératoire. Palpation cervicale : adénopathies sous-maxillaires bilatérales, mobiles, indolores (1,5 cm à droite, 2 cm à gauche). Foie palpable à 3 travers de doigt sous le rebord costal, lisse, indolore. Pas d’œdème des membres inférieurs.
#
# ### Examens complémentaires
# - **NFS** : Hb 12,8 g/dL, leucocytes 7,2 G/L (PNN 5,1 G/L), plaquettes 210 G/L.
# - **Bilan hépatique** : bilirubine totale 12 µmol/L (N), ASAT 45 UI/L (N < 35), ALAT 52 UI/L (N < 45), PAL 180 UI/L (N < 130), GGT 150 UI/L (N < 60).
# - **Créatinine** : 98 µmol/L (DFG estimé à 55 mL/min).
# - **TDM cervico-thoraco-abdominale** (03/10/2024) : stabilité des adénopathies cervicales (plus grande à 22 mm en court axe, identique à l’examen de juillet 2024) et des lésions hépatiques secondaires (5 lésions, la plus grande mesurant 35 mm dans le segment VI). Pas de nouvelle lésion suspecte.
# - **Échocardiographie** (réalisée en cardiologie le même jour) : sténose aortique serrée (surface valvulaire 0,8 cm², gradient moyen 45 mmHg), FEVG conservée à 60%.
#
# ### Évolution pendant l'hospitalisation
# La journée est marquée par :
# 1. **Consultation dermatologique** : examen clinique négatif pour une récidive cutanée. Discussion sur la surveillance future (consultation trimestrielle + imagerie semestrielle).
# 2. **Avis oncologique** : en raison de la stabilité radiologique et de l’absence de symptômes, décision de maintenir une surveillance active sans introduction de traitement systémique (chimiothérapie ou immunothérapie) pour l’instant. Le patient et sa famille sont informés des options thérapeutiques en cas de progression (pembrolizumab en monothérapie ou association 5-FU + carboplatine).
# 3. **Avis cardiologique** : la sténose aortique est asymptomatique (pas de syncope, angor ou dyspnée). Un suivi échographique annuel est proposé, avec discussion d’un remplacement valvulaire en cas de symptomatologie.
# 4. **Consultation diététique** : renforcement des conseils hygiéno-diététiques (régime hypocalorique équilibré, activité physique adaptée). Objectif de perte de poids à 5-10% en 6 mois.
#
# ### Conclusion
# M. Traoré présente un carcinome épidermoïde métastatique du cuir chevelu (ganglions cervicaux et foie) avec une maladie stable sous surveillance après traitement local. Les comorbidités (sténose aortique, obésité) sont prises en charge de manière conservatrice. Le patient rentre à domicile avec :
# - Un rendez-vous en dermatologie dans 3 mois.
# - Une TDM de contrôle prévue en mars 2025.
# - Un suivi cardiologique programmé en décembre 2024.
# - Une prise en charge nutritionnelle renforcée.
#
# Pas de modification thérapeutique majeure à ce stade.
#
# Dr Ciara Samine
# Service de Dermatologie, CHU Purpan, Toulouse
# ",
#
#   "formulations": {
#     "diagnostics": {
#       "C444 - Tumeur maligne de la peau du cuir chevelu et du cou": [
#         "carcinome épidermoïde cutané du cuir chevelu",
#         "carcinome épidermoïde infiltrant",
#         "lésion ulcéro-bourgeonnante du cuir chevelu",
#         "tumeur primitive",
#         "récidive cutanée",
#         "récidive locale au niveau de la cicatrice opératoire"
#       ],
#       "I350 - Sténose (de la valvule) aortique (non rhumatismale)": [
#         "sténose aortique non rhumatismale",
#         "sténose aortique serrée",
#         "souffle systolique au foyer aortique"
#       ],
#       "C770 - Tumeur maligne secondaire et non précisée des ganglions lymphatiques de la tête, de la face et du cou": [
#         "adénopathies cervicales bilatérales",
#         "adénopathies sous-maxillaires bilatérales",
#         "ganglions cervicaux métastatiques",
#         "métastases ganglionnaires cervicales"
#       ],
#       "C798 - Tumeur maligne secondaire d'autres sièges précisés": [
#         "métastases à distance"
#       ],
#       "C787 - Tumeur maligne secondaire du foie et des voies biliaires intrahépatiques": [
#         "métastases hépatiques multiples",
#         "lésions hépatiques secondaires",
#         "foie métastatique"
#       ],
#       "E6695 - Obésité sans précision de l'adulte avec indice de masse corporelle [IMC] égal ou supérieur à 35 kg/m² et inférieur à 40 kg/m²": [
#         "obésité morbide (IMC à 37 kg/m²)",
#         "obésité (IMC 35,5 kg/m²)",
#         "surpoids majeur"
#       ]
#     },
#
#     "informations": {
#       "Âge": [
#         "80 ans"
#       ],
#       "Sexe": [
#         "masculin",
#         "homme"
#       ],
#       "État général": [
#         "en bon état général (ECOG 1)",
#         "conscience conservée, patient orienté"
#       ],
#       "Comorbidités": [
#         "sténose aortique non rhumatismale, diagnostiquée en 2020",
#         "obésité morbide (IMC à 37 kg/m²)"
#       ],
#       "Topographie de la tumeur primaire": [
#         "cuir chevelu",
#         "peau du cuir chevelu et du cou"
#       ],
#       "Histologie tumorale": [
#         "carcinome épidermoïde infiltrant",
#         "carcinome épidermoïde cutané"
#       ],
#       "Stade tumoral": [
#         "pT3N2cM1",
#         "métastases ganglionnaires cervicales et hépatiques",
#         "adénopathies cervicales bilatérales (N2c) et métastases hépatiques multiples (M1)"
#       ],
#       "Biomarqueurs tumoraux": [
#         "statut PD-L1 positif (CPS > 20)",
#         "pas de mutation BRAF ou EGFR détectée"
#       ],
#       "Sites métastatiques": [
#         "ganglions lymphatiques cervicaux",
#         "foie (métastases hépatiques multiples)",
#         "adénopathies sous-maxillaires bilatérales",
#         "5 lésions hépatiques secondaires"
#       ],
#       "Évolutivité tumorale": [
#         "maladie stable sous surveillance",
#         "stabilité des adénopathies cervicales et des lésions hépatiques secondaires",
#         "pas de nouvelle lésion suspecte à l’imagerie"
#       ],
#       "Examens pour diagnostic initial": [
#         "biopsie cutanée",
#         "TDM cervico-thoraco-abdomino-pelvien initial",
#         "PET-scan initial"
#       ],
#       "Examens d'évaluation du stade tumoral": [
#         "TDM cervico-thoraco-abdomino-pelvien",
#         "PET-scan",
#         "échographie hépatique (si réalisée antérieurement)"
#       ],
#       "Examens d’évaluation de l’évolutivité tumorale": [
#         "TDM de contrôle (03/10/2024)",
#         "comparaison avec la TDM de juillet 2024",
#         "examen clinique dermatologique"
#       ],
#       "Traitements antitumoraux": [
#         "exérèse large de la lésion primitive avec reconstruction par lambeau local",
#         "radiothérapie adjuvante (50 Gy en 25 fractions)",
#         "surveillance active sans traitement systémique"
#       ],
#       "Lignes de traitement antitumoral": [
#         "traitement local en première ligne (chirurgie + radiothérapie)",
#         "pas de ligne systémique initiée à ce stade"
#       ],
#       "Médicaments antitumoraux": [
#         "aucun traitement médicamenteux antitumoral en cours",
#         "discussion sur pembrolizumab ou 5-FU + carboplatine en cas de progression"
#       ],
#       "Cycles de chimiothérapie": [
#         "aucun cycle administré à ce jour"
#       ],
#       "NFS": [
#         "Hb 12,8 g/dL, leucocytes 7,2 G/L (PNN 5,1 G/L), plaquettes 210 G/L",
#         "pas d’anémie ni de thrombopénie"
#       ],
#       "Créatinine": [
#         "98 µmol/L (DFG estimé à 55 mL/min)",
#         "fonction rénale légèrement altérée"
#       ],
#       "Bilan hépatique": [
#         "bilirubine totale normale (12 µmol/L)",
#         "ASAT à 45 UI/L, ALAT à 52 UI/L (légère cytolyse)",
#         "PAL à 180 UI/L et GGT à 150 UI/L (cholestase modérée)",
#         "perturbations hépatiques attribuées aux métastases"
#       ]
#     }
#   }
# }
# ```

# %%
df_scenario.loc[0,"prefix_len"]
# Out:
# 287
